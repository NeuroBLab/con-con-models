# %%
import random
import datajoint as dj
from microns_phase3 import nda, utils
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import random
#       2 import datajoint as dj
# ----> 3 from microns_phase3 import nda, utils
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'microns_phase3'

# %%
from ccmodels.preprocessing.selectivity import cell_area_identifiers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ccmodels.preprocessing.selectivity import cell_area_identifiers
#
# ModuleNotFoundError: No module named 'ccmodels'
